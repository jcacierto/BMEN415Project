# %%
import os 
from keras.utils import np_utils
import seaborn as sns 
from tensorflow.keras.initializers import RandomNormal
import PIL

import matplotlib.pyplot as plt
import numpy as np
import time
from zipfile import ZipFile

import cv2 as cv
from google.colab.patches import cv2_imshow

# %%
#import folder to session:
fp = '/content/CTScan_Cancer.zip'

with ZipFile(fp, 'r') as zip:
  zip.extractall()

print('done')
# Out:
# done

# %%
#plt.imread('/content/Data/test/adenocarcinoma/000114 (5).png')
#cv2_imshow('/content/Data/test/adenocarcinoma/000114 (5).png')
PIL.Image.open('/content/Data/test/adenocarcinoma/000108 (3).png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=381x282 at 0x7F235F1CAED0>
